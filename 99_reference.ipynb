# %% [markdown]
# # `lunapi` : reference
#
# Links to notebooks in this repository: [Index](./00_overview.ipynb) | [Luna tutorial](./tutorial.ipynb) |
# [Individuals](./01_indivs.ipynb) | [Projects](./02_projects.ipynb) | [Staging](./03_staging.ipynb) | [Models](./04_models.ipynb) | [Advanced](./98_advanced.ipynb) | [Reference](./99_reference.ipynb)
#
# ---

# %% [markdown]
# ## API reference
#
# The canonical generated `lunapi` API reference is here:
#
# [https://remnrem.github.io/luna-api/index.html](https://remnrem.github.io/luna-api/index.html)
#
# Use that page for method signatures, arguments, return values, and module-level details.

# %% [markdown]
# ## Very brief orientation
#
# Most notebook workflows use `import lunapi as lp`, then one of two main entry points:
#
# - `lp.proj()` for sample lists, project-level variables, and running Luna commands across many records.
# - `lp.inst(...)` or `proj.inst(...)` for attaching one EDF/annotation set, inspecting it, running commands, extracting data, and plotting.
#
# This notebook intentionally does not duplicate the generated API docs, so it does not become a stale partial reference.
